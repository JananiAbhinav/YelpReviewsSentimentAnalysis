# %%
# !pip install pymongo kafka-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.5/246.5 kB 24.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 27.8 MB/s eta 0:00:00
# ...

# %%
import pymongo,json
from kafka import KafkaConsumer

# %%
client = pymongo.MongoClient("mongodb+srv://shunmugaa:IISc2024@dataenggcluster.oos60.mongodb.net/yelp")
db = client["yelp"]
collection = db["reviews"]

# %%
consumer = KafkaConsumer(
    'reviews',
    bootstrap_servers=['pkc-xrnwx.asia-south2.gcp.confluent.cloud:9092'],
    security_protocol='SASL_SSL',
    sasl_mechanism='PLAIN',
    sasl_plain_username='L5TEVAYKNYRO3VVF',
    sasl_plain_password='uSyvdswvZgWyZoNPycDwCRsklSZmJ4qZG3FrgAAKqwhNEV/pq0O15o4jfTR5S9ye'
)
# Out:
# WARNING:kafka.coordinator.consumer:group_id is None: disabling auto-commit.

# %%
for message in consumer:
    print(message)
    if message is None:
        continue
    else:
    # Decode the message value (assuming it's JSON-encoded)
      data = json.loads(message.value.decode('utf-8'))
      print(data)
    # Insert the data into MongoDB
      collection.insert_one(data)

      print(f"Inserted data: {data}")
# Out:
# ERROR:kafka.conn:<BrokerConnection node_id=11 host=b11-pkc-xrnwx.asia-south2.gcp.confluent.cloud:9092 <connected> [IPv4 ('34.131.81.179', 9092)]>: socket disconnected
# WARNING:kafka.client:Node 11 connection failed -- refreshing metadata
# ERROR:kafka.consumer.fetcher:Fetch to node 11 failed: KafkaConnectionError: socket disconnected
# ERROR:kafka.conn:<BrokerConnection node_id=4 host=b4-pkc-xrnwx.asia-south2.gcp.confluent.cloud:9092 <connected> [IPv4 ('34.131.10.37', 9092)]>: socket disconnected
# WARNING:kafka.client:Node 4 connection failed -- refreshing metadata
# ERROR:kafka.consumer.fetcher:Fetch to node 4 failed: KafkaConnectionError: socket disconnected
# ERROR:kafka.conn:<BrokerConnection node_id=2 host=b2-pkc-xrnwx.asia-south2.gcp.confluent.cloud:9092 <connected> [IPv4 ('34.131.237.160', 9092)]>: socket disconnected
# WARNING:kafka.client:Node 2 connection failed -- refreshing metadata
# ...
